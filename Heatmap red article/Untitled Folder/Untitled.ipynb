# %%
import numpy as np
import matplotlib.pyplot as plt
b, a = np.meshgrid(np.linspace(25, 1025, 21), np.linspace(5, 505, 51))

with open("asd.txt") as textFile:
    c = [np.float_(line.split()) for line in textFile]

with open("x.txt") as textFile:
    x = [np.float_(line.split()) for line in textFile]    
with open("y.txt") as textFile:
    y = [np.float_(line.split()) for line in textFile]    

l_a=a.min()
r_a=a.max()
l_b=b.min()
r_b=b.max()

l_c,r_c  = np.abs(c).min(), np.abs(c).max()

figure, axes = plt.subplots()

c = axes.pcolormesh(b, a, c, cmap='hot', vmin=l_c, vmax=r_c)

axes.set_title('The order parameter for the network with full synchronization')
axes.set_ylabel('Inter spike intervals')
axes.set_xlabel('Number of neurons')

axes.axis([ l_b, r_b,l_a, r_a])
figure.colorbar(c)

plt.plot(x,y, linewidth=2, color='silver')

#plt.show()

plt.savefig("myplot.png", dpi = 1000)

# %%
b, a = np.meshgrid(np.linspace(25, 1025, 201), np.linspace(1, 501, 201))
with open("syncs.txt") as textFile:
    c = [np.float_(line.split()) for line in textFile]


l_a=a.min()
r_a=a.max()
l_b=b.min()
r_b=b.max()

l_c,r_c  = np.abs(c).min(), np.abs(c).max()

figure, axes = plt.subplots()

c = axes.pcolormesh(b, a, c, cmap='hot', vmin=l_c, vmax=r_c)

axes.set_title('The order parameter for the network with full synchronization')
axes.set_ylabel('Inter spike intervals')
axes.set_xlabel('Number of neurons')

axes.axis([ l_b, r_b,l_a, r_a])
figure.colorbar(c)

#plt.plot(cc,cc, linewidth=2, color='silver')

#plt.show()

plt.savefig("syncs.png", dpi = 1000)

# %%
a
# Out:
# array([[  1. ,   1. ,   1. , ...,   1. ,   1. ,   1. ],
#        [  3.5,   3.5,   3.5, ...,   3.5,   3.5,   3.5],
#        [  6. ,   6. ,   6. , ...,   6. ,   6. ,   6. ],
#        ...,
#        [496. , 496. , 496. , ..., 496. , 496. , 496. ],
#        [498.5, 498.5, 498.5, ..., 498.5, 498.5, 498.5],
#        [501. , 501. , 501. , ..., 501. , 501. , 501. ]])

# %%
binary
# Out:
# array([[  25.,   30.,   35., ..., 1015., 1020., 1025.],
#        [  25.,   30.,   35., ..., 1015., 1020., 1025.],
#        [  25.,   30.,   35., ..., 1015., 1020., 1025.],
#        ...,
#        [  25.,   30.,   35., ..., 1015., 1020., 1025.],
#        [  25.,   30.,   35., ..., 1015., 1020., 1025.],
#        [  25.,   30.,   35., ..., 1015., 1020., 1025.]])

# %%
b, a = np.meshgrid(np.linspace(25, 1025, 201), np.linspace(1, 501, 201))
with open("binary.txt") as textFile:
    c = [np.float_(line.split()) for line in textFile]

l_a=a.min()
r_a=a.max()
l_b=b.min()
r_b=b.max()

l_c,r_c  = np.abs(c).min(), np.abs(c).max()

figure, axes = plt.subplots()

c = axes.pcolormesh(b, a, c, cmap='hot', vmin=l_c, vmax=r_c)

axes.set_title('The order parameter for the network with full synchronization')
axes.set_ylabel('Inter spike intervals')
axes.set_xlabel('Number of neurons')

axes.axis([ l_b, r_b,l_a, r_a])
figure.colorbar(c)

#plt.plot(x,y, linewidth=2, color='silver')

#plt.show()

plt.savefig("binary.png", dpi = 1000)
